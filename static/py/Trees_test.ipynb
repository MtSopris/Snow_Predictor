# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("../data/bulk_data.csv"))
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x        Date Station Name  \
# 0           0           0.0  2000-01-01     Apishapa
# 1           1           1.0  2000-01-02     Apishapa
# 2           2           2.0  2000-01-03     Apishapa
# 3           3           3.0  2000-01-04     Apishapa
# 4           4           4.0  2000-01-05     Apishapa
#
#    Snow Water Equivalent (in) Start of Day Values  \
# 0                                             4.1
# 1                                             4.1
# 2                                             4.1
# 3                                             4.1
# 4                                             4.5
#
#    Change In Snow Water Equivalent (in)  Snow Depth (in) Start of Day Values  \
# 0                                   0.4                                 12.0
# 1                                   0.0                                 12.0
# 2                                   0.0                                 12.0
# ...

# %%
df['Change In Snow Depth (in)'].describe()
# Out:
# count    654487.000000
# mean         -0.018306
# std          11.897779
# min        -340.000000
# 25%          -1.000000
# 50%           0.000000
# 75%           0.000000
# max         341.000000
# Name: Change In Snow Depth (in), dtype: float64

# %%
bins = [-340, 0, 341]
labels = ['Melt','None','Snow']
df['binned'] = pd.cut(df['Change In Snow Depth (in)'], bins=bins, labels=labels)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-36c6222ed5c9> in <module>
#       1 bins = [-340, 0, 341]
#       2 labels = ['Melt','None','Snow']
# ----> 3 df['binned'] = pd.cut(df['Change In Snow Depth (in)'], bins=bins, labels=labels)
#       4 df
#       5
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     282         dtype=dtype,
#     283         duplicates=duplicates,
# --> 284         ordered=ordered,
#     285     )
#     286
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\pandas\core\reshape\tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     433             if len(labels) != len(bins) - 1:
#     434                 raise ValueError(
# ...

# %%
df['Change In Snow Depth (in)'].unique()
# Out:
# array([   0.,    3.,   -1.,   nan,   -2.,    2.,    1.,    4.,   -3.,
#           7.,   -5.,   -4.,    5.,    9.,    6.,   16.,    8.,   12.,
#          73.,  -66.,   11.,   -6.,  127., -125.,  123., -105.,   10.,
#         190., -185.,  162., -156.,   13.,  152., -149.,  139., -133.,
#          52.,   59.,  -57.,   87.,  -83.,   84.,  -77.,   78.,  -73.,
#          63.,  -59.,   62.,  -61.,   61.,  -62.,   64.,   22.,  -20.,
#          18.,  -15.,   21.,  -17.,   30.,  -28.,   75.,  -75.,   69.,
#         107., -101.,   90.,  -86.,  134.,  -99.,   99., -121.,  121.,
#         111., -114.,  112., -104.,  103.,  -97.,   95.,  -90.,   89.,
#         -88.,   85.,  125., -119., -110.,   17.,   -7.,   91.,   66.,
#         -46.,   -9.,   93.,  -87.,   15.,   19.,   -8.,  -91.,  118.,
#        -117., -113.,  113., -111., -102.,  101.,   94.,  -98.,   45.,
#         -42.,   58.,  -50.,   27.,  -27.,  120.,   14.,   20.,  -22.,
# ...

# %%
target = df['binned']
target_names = ['Melt','None','Snow']

# %%
data = df.drop('binned', axis=1)
feature_names = data.columns
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x        Date Station Name  \
# 0           0           0.0  2000-01-01     Apishapa
# 1           1           1.0  2000-01-02     Apishapa
# 2           2           2.0  2000-01-03     Apishapa
# 3           3           3.0  2000-01-04     Apishapa
# 4           4           4.0  2000-01-05     Apishapa
#
#    Snow Water Equivalent (in) Start of Day Values  \
# 0                                             4.1
# 1                                             4.1
# 2                                             4.1
# 3                                             4.1
# 4                                             4.5
#
#    Change In Snow Water Equivalent (in)  Snow Depth (in) Start of Day Values  \
# 0                                   0.4                                 12.0
# 1                                   0.0                                 12.0
# 2                                   0.0                                 12.0
# ...

# %%
dates=data['Date'].astype('datetime64[ns]')
dates=dates.dt.dayofyear
df['Date']=dates
one_hot = pd.get_dummies(data['Station Name'])
# Drop column as it is now encoded
df1 = data.drop(['Station Name'],axis = 1)
# Join the encoded df
testing_df = df1.join(one_hot)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-919dfd680ef1> in <module>
#       1 clf = tree.DecisionTreeClassifier()
# ----> 2 clf = clf.fit(X_train, y_train)
#       3 clf.score(X_test, y_test)
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     900             sample_weight=sample_weight,
#     901             check_input=check_input,
# --> 902             X_idx_sorted=X_idx_sorted)
#     903         return self
#     904
#
# ~\anaconda3\envs\PythonAdv\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     156             X, y = self._validate_data(X, y,
#     157                                        validate_separately=(check_X_params,
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=200)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.72916666666666663

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.2604038892633122, 'Glucose'),
#  (0.16240738779159666, 'BMI'),
#  (0.1437077712983523, 'Age'),
#  (0.12126276641273467, 'DiabetesPedigreeFunction'),
#  (0.088871399128041817, 'BloodPressure'),
#  (0.079222898914976206, 'Pregnancies'),
#  (0.07440650942444979, 'Insulin'),
#  (0.069717377766536262, 'SkinThickness')]
